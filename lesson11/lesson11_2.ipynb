# %%
#有一個names.txt
#讀取names.txt
#請隨機取出3個名字
import random
from pprint import pprint

def sample_names_from_file(file_name: str, nums: int = 1) -> list[str]:
    """
    從指定的檔案中讀取所有姓名，並隨機取出指定數量的姓名。

    參數:
        file_name (str): 檔案名稱，檔案內容為姓名，每行一個。
        nums (int): 要隨機取出的姓名數量，預設為1。

    回傳:
        list[str]: 隨機取出的姓名列表。
    """
    with open(file_name, encoding="utf-8") as file:
        content: str = file.read()
        names: list[str] = content.split()
        return random.sample(names, nums)

def generate_scores_for_names(names: list[str]) -> list[dict]:
    """
    為每個姓名生成3個隨機分數。

    參數:
        names (list[str]): 姓名列表。

    回傳:
        list[dict]: 包含姓名和3個隨機分數的2維列表。
    """
    result_list = []
    for person_name in names:
        student_scores:dict = {"姓名":person_name}
        for subject in ["國文", "英文", "數學"]:
            student_scores[subject] = random.randint(50, 100) 
        result_list.append(student_scores)

    return result_list

def main():
    names: list[str] = sample_names_from_file("names.txt", nums=50)
    students: list[dict] = generate_scores_for_names(names)
    pprint(students)

if __name__ == "__main__":
    main()
# Out:
# [{'國文': 96, '姓名': '劉嘉泰', '數學': 89, '英文': 84},
#  {'國文': 85, '姓名': '楊韻如', '數學': 75, '英文': 99},
#  {'國文': 99, '姓名': '周芷蓁', '數學': 63, '英文': 76},
#  {'國文': 78, '姓名': '張慧君', '數學': 59, '英文': 94},
#  {'國文': 58, '姓名': '陳文賢', '數學': 99, '英文': 100},
#  {'國文': 54, '姓名': '蕭淑華', '數學': 94, '英文': 72},
#  {'國文': 70, '姓名': '方筠紹', '數學': 80, '英文': 93},
#  {'國文': 62, '姓名': '陳淑娟', '數學': 82, '英文': 60},
#  {'國文': 61, '姓名': '吳晴洋', '數學': 87, '英文': 99},
#  {'國文': 64, '姓名': '黃淑芬', '數學': 72, '英文': 78},
#  {'國文': 71, '姓名': '林淑安', '數學': 87, '英文': 87},
#  {'國文': 64, '姓名': '王良斌', '數學': 92, '英文': 91},
#  {'國文': 87, '姓名': '陳信宏', '數學': 74, '英文': 91},
#  {'國文': 78, '姓名': '林冠蕙', '數學': 92, '英文': 98},
#  {'國文': 97, '姓名': '陳淑萍', '數學': 88, '英文': 63},
#  {'國文': 53, '姓名': '林志喜', '數學': 50, '英文': 87},
#  {'國文': 81, '姓名': '蔡孟泉', '數學': 64, '英文': 64},
#  {'國文': 51, '姓名': '郭坤花', '數學': 68, '英文': 59},
#  {'國文': 90, '姓名': '劉依婷', '數學': 86, '英文': 75},
#  {'國文': 69, '姓名': '林建勳', '數學': 93, '英文': 81},
#  {'國文': 94, '姓名': '黃婷婷', '數學': 94, '英文': 51},
#  {'國文': 51, '姓名': '胡姿婷', '數學': 65, '英文': 57},
#  {'國文': 90, '姓名': '黃旻林', '數學': 66, '英文': 95},
#  {'國文': 63, '姓名': '白世宏', '數學': 88, '英文': 82},
#  {'國文': 55, '姓名': '藍姿婷', '數學': 90, '英文': 81},
#  {'國文': 91, '姓名': '黃翔杰', '數學': 78, '英文': 78},
#  {'國文': 56, '姓名': '洪阿惠', '數學': 81, '英文': 76},
#  {'國文': 96, '姓名': '張明惟', '數學': 84, '英文': 100},
#  {'國文': 57, '姓名': '林義皓', '數學': 99, '英文': 65},
#  {'國文': 60, '姓名': '王孝純', '數學': 83, '英文': 86},
#  {'國文': 53, '姓名': '鄭淑珍', '數學': 75, '英文': 73},
#  {'國文': 65, '姓名': '李佳彥', '數學': 53, '英文': 100},
#  {'國文': 94, '姓名': '張韋成', '數學': 72, '英文': 99},
#  {'國文': 89, '姓名': '王雅慧', '數學': 98, '英文': 53},
#  {'國文': 66, '姓名': '陳怡容', '數學': 52, '英文': 71},
#  {'國文': 89, '姓名': '楊火帆', '數學': 97, '英文': 53},
#  {'國文': 53, '姓名': '沈心利', '數學': 71, '英文': 86},
#  {'國文': 66, '姓名': '黃志福', '數學': 86, '英文': 52},
#  {'國文': 78, '姓名': '蒙淑惠', '數學': 52, '英文': 94},
#  {'國文': 73, '姓名': '馮淑芬', '數學': 98, '英文': 72},
#  {'國文': 82, '姓名': '林玉佩', '數學': 57, '英文': 60},
#  {'國文': 97, '姓名': '簡美君', '數學': 52, '英文': 82},
#  {'國文': 95, '姓名': '蔡嘉音', '數學': 78, '英文': 88},
#  {'國文': 81, '姓名': '郭淑真', '數學': 62, '英文': 83},
#  {'國文': 71, '姓名': '陳俊憲', '數學': 79, '英文': 83},
#  {'國文': 63, '姓名': '林康亮', '數學': 72, '英文': 84},
#  {'國文': 67, '姓名': '呂傑宣', '數學': 92, '英文': 84},
#  {'國文': 66, '姓名': '黃善迪', '數學': 54, '英文': 70},
#  {'國文': 96, '姓名': '趙偉銘', '數學': 89, '英文': 75},
#  {'國文': 58, '姓名': '周琬婷', '數學': 93, '英文': 63}]

# %%
#有一個names.txt
#讀取names.txt
#請隨機取出3個名字
import random
from pprint import pprint

random.seed(4561)

def sample_names_from_file(file_name: str, nums: int = 1) -> list[str]:
    """
    從指定的檔案中讀取所有姓名，並隨機取出指定數量的姓名。

    參數:
        file_name (str): 檔案名稱，檔案內容為姓名，每行一個。
        nums (int): 要隨機取出的姓名數量，預設為1。

    回傳:
        list[str]: 隨機取出的姓名列表。
    """
    with open(file_name, encoding="utf-8") as file:
        content: str = file.read()
        names: list[str] = content.split()
        return random.sample(names, nums)

def generate_scores_for_names(names: list[str]) -> list[dict]:
    """
    為每個姓名生成3個隨機分數。

    參數:
        names (list[str]): 姓名列表。

    回傳:
        list[dict]: 包含姓名和3個隨機分數的2維列表。
    """
    result_list = []
    for person_name in names:
        student_scores:dict = {"姓名":person_name}
        for subject in ["國文", "英文", "數學"]:
            student_scores[subject] = random.randint(50, 100) 
        result_list.append(student_scores)

    return result_list

#建立一個function,傳入students
#儲存為students.csv檔
def save_students_to_csv(students: list[dict], file_name: str = "students.csv") -> None:
    """
    將學生資料儲存為CSV檔案。

    參數:
        students (list[dict]): 學生資料列表。
        file_name (str): 要儲存的CSV檔案名稱，預設為"students.csv"。
    """
    import csv
    with open(file_name, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=students[0].keys())
        writer.writeheader()
        writer.writerows(students)


def main():
    names: list[str] = sample_names_from_file("names.txt", nums=50)
    students: list[dict] = generate_scores_for_names(names)
    save_students_to_csv(students)

if __name__ == "__main__":
    main()
