# %%
#1家分站30天的營收
import numpy as np
one_store = np.random.randint(100,10000,size=(30,))
one_store
# Out:
# array([9558, 4971, 6908, 8521, 6363, 4517, 7506, 6863, 2881, 5041, 2873,
#        9146, 2533, 1366, 5991, 7700, 1363, 1500, 6141, 4858, 9845, 8386,
#        1926,  710, 4578, 1318, 4863, 5971, 5111, 3064], dtype=int32)

# %%
#累計每天這家店的營收
oneStoreCum = one_store.cumsum()
oneStoreCum
# Out:
# array([  9558,  14529,  21437,  29958,  36321,  40838,  48344,  55207,
#         58088,  63129,  66002,  75148,  77681,  79047,  85038,  92738,
#         94101,  95601, 101742, 106600, 116445, 124831, 126757, 127467,
#        132045, 133363, 138226, 144197, 149308, 152372])

# %%
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(111)
axes.plot(range(1, 31), oneStoreCum, marker='o', linestyle='-', color='r', label='Cumulative Revenue')
axes.set_title('Cumulative Revenue Over Time')
axes.set_xlabel('Days')
axes.set_ylabel('Revenue')
axes.legend()
axes.grid()
plt.show()
